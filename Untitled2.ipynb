# %%
text='Python is a fun programming language'
print(text.split('n',5))
# Out:
# ['Pytho', ' is a fu', ' programmi', 'g la', 'guage']

# %%
text='Python, is,    a,fun,     programming,    language'
print(text.split(',     '  ))
# Out:
# ['Python, is,    a,fun', 'programming,    language']

# %%
text='Python is a fun programming language'
