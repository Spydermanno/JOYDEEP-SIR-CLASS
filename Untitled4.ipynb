# %%
a=10
b=20

# %%
print(a+b) #addition
# Out:
# 30

# %%
a-b      #subtraction
# Out:
# -10

# %%
print(a%b)  #modulo
# Out:
# 10

# %%
10**20
# Out:
# 100000000000000000000

# %%
9//2 #floor division
# Out:
# 4

# %%
9/2   #float division
# Out:
# 4.5

# %%
pow(10,20) #power
# Out:
# 100000000000000000000

# %%
a*b   #multiplication
# Out:
# 200

# %%
C

# %% [markdown]
# Comparison or relational operators

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a<>b #This operatipn was depreciated in python 3.9
# Out:
#   File "<ipython-input-11-fee3b88270fa>", line 1
#     a<>b
#       ^
# SyntaxError: invalid syntax

# %%
a>b  #Greater than
# Out:
# False

# %%
a<b  #less than
# Out:
# True

# %%
a>=b  #Greater than or equal to
# Out:
# False

# %%
a<=b  #less than or equal to
# Out:
# True

# %%
a<=b  #a<b or a==b

# %% [markdown]
# Assignment operator

# %%
c=a+b
print(c)
# Out:
# 30

# %%
c=a+b #it wil return 30 and not print 30

# %%
print(c+=a)
# Out:
#   File "<ipython-input-18-e98095f747da>", line 1
#     print(c+=a)
#             ^
# SyntaxError: invalid syntax

# %%
print(c+=a)
# Out:
#   File "<ipython-input-19-e98095f747da>", line 1
#     print(c+=a)
#             ^
# SyntaxError: invalid syntax

# %%
c+=a
print(c)
# Out:
# 40

# %%
#No assignment operator in print statement in python

# %%
c-=a
print(c)
# Out:
# 30

# %%
c*=a
print(c)
# Out:
# 300

# %%
c/=a #c is divided by a and the value is assigned to c
print(c) #a=10 b=20 c=300
# Out:
# 30.0

# %%
c%=a  #datattype is converted to  float ,then modulus  operation takes place followed by an asasignment 
      #a=10,b=20,c=0.0

# %%
c**=a  # datatype of a is converted to float,then a function is called and the value is returned to a  power operation and then assignment operation is done
print(c)
# Out:
# 590490000000000.0

# %%
c//=a
print(c)
# Out:
# 59049000000000.0

# %%
c=0.0
c//=a
print(c)
# Out:
# 0.0

# %%
20.0//10
# Out:
# 2.0

# %%
9//2.0 #Concept of parent variable and flooring
# Out:
# 4.0

# %%
c=60 #a=0011 1100
d=13 #b=0000 1101

# %%
e=c&d
print(e)
# Out:
# 12

# %%
f=c^d  #c=0000 1100  (#c=0011 1101)
print(f)
# Out:
# 49

# %%
~e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-33545eaae9ed> in <module>
# ----> 1 ~e
#
# NameError: name 'e' is not defined

# %%
g=60
h=g<<2 
print(h)
# Out:
# 240

# %%
rso

# %%
#every right shift/ 2 nokila jidhar h
#every left shift * 2

# %%
i=60>>2
print(i)
# Out:
# 15

# %% [markdown]
# Logical operators

# %%
a=10

# %%
b=20

# %%
a and b
# Out:
# 20

# %%
b and a
# Out:
# 10

# %%
a=10
b=False
print(a and b)
# Out:
# False

# %%
a=10
b=not(50)
c=0

# %%
a or b
# Out:
# 10

# %%
b or a
# Out:
# 20

# %%
b=0
a=10
a or b
# Out:
# 10

# %%
not(20)
# Out:
# False

# %%
not(50)
# Out:
# False

# %%
a=10
b=not(50)
c=0
a and b and c
# Out:
# False

# %%
a=False
b=20
c=0

# %%
not(True)
# Out:
# False

# %%
a and c
# Out:
# False

# %%
b and c and a
# Out:
# 0

# %%
c and a and b
# Out:
# 0

# %%
a and b and c
# Out:
# False

# %%
a and b or c
# Out:
# 0

# %%
a=10

b=10
c=0
print(a and b and c)
# Out:
# 0

# %% [markdown]
# Membership operator

# %%
string1="My name is Joy"
#if 'is' is present in this string
#we run a for loop in c to check whether a word is there in c or not
#in is a keyword
print('name is' in string1)
# Out:
# True

# %%
print('Name is' in string1)
# Out:
# False

# %%
#Ascii value of n and N is different for interview purposes

# %%
print('Name is' not in string1)
# Out:
# True

# %% [markdown]
# Identity operators

# %%
#same objects ==True
#otherwise false

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
a=0
b=False
a is b
# Out:
# False

# %%
a=50
b=True
a is b
# Out:
# False

# %%
a=50
b='50'
a is b
# Out:
# False

# %%
a= 50
b='50'
a is int(b)
# Out:
# True

# %%
a=50

# %%
print(str(a))
# Out:
# 50

# %%
print(b)
# Out:
# 50

# %%
print(a)
# Out:
# 50

# %%
#Conversion of a string into number is not possible

# %%
50 is stored in one of the memory locations when we do a=50
python works on call by reference.

# %%
print(id(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-186eb25ff3c5> in <module>
# ----> 1 print(id(a))
#
# NameError: name 'a' is not defined

# %%
print(id(False))
# Out:
# 11041440

# %%
print(id(0))
# Out:
# 11256032

# %%
'String'   #Python as a language uses both single and double quotes.

# %%
x='123'
y=1+x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d73d2d05eb25> in <module>
#       1 x='123'
# ----> 2 y=1+x
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x='123'
y=x+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7d2307f68e32> in <module>
#       1 x='123'
# ----> 2 y=x+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Learn about both the errors

# %%
name=int(input("Enter your name"))
# Out:
# Enter your nameAnkit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-29594cd5ab15> in <module>
# ----> 1 name=int(input("Enter your name"))
#
# ValueError: invalid literal for int() with base 10: 'Ankit'

# %%
numberofApples=int(input("Enter the no of apples"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-051f2de4c896> in <module>
# ----> 1 numberofApples=int(input("Enter the no of apples"))
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# ...

# %%
#int(input)     INDUSTRY BASED PRACTICE

# %%
fruit='banana'
index=0
while(index<len(fruit)):
  letter=fruit[index]
  print(index,letter)
  index=+=1
  print(index)
# Out:
# 0 b
# 1
# 1 a
# 2
# 2 n
# 3
# 3 a
# 4
# 4 n
# 5
# 5 a
# 6

# %%
fruit='banana'
index=0
while(index<=len(fruit)):
  letter=fruit[index]
  print(index,letter)
  index=index+1
  print(index)
# Out:
# 0 b
# 1
# 1 a
# 2
# 2 n
# 3
# 3 a
# 4
# 4 n
# 5
# 5 a
# 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-ab258b9435ec> in <module>
#       2 index=0
#       3 while(index<=len(fruit)):
# ----> 4   letter=fruit[index]
#       5   print(index,letter)
#       6   index=index+1
#
# IndexError: string index out of range

# %%
#index out of range error

# %%
fruit='apple'
index=0
for i in fruit:                  #revise using pomodoros
  print(i)
# Out:
# a
# p
# p
# l
# e

# %%
#native python libraries for a string

# %%
s='Hello Python'

# %%
print(s[4:5])
# Out:
# o

# %%
print(s[:5])
# Out:
# Hello

# %%
print(s[4:])
# Out:
# o Python

# %%
print(s[::])
# Out:
# Hello Python

# %%
print(s[:])
# Out:
# Hello Python

# %%
fruit='apple'

# %%
'p' in fruit  #revise using pomodoros
# Out:
# True

# %%
if 'k' in fruit:
  print('Found')

# %%
a='Hello'
b=' '
z='There'
c=a+' '+z

# %%
print(c)
# Out:
# Hello There

# %%
if word<'Matched':
     print('Your word, '+word+ ',comes before banana')     #Don't use bracket with if and else
elif word

# %%
print(word<'banana')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-33b44238b5af> in <module>
# ----> 1 print(word<'banana')
#
# NameError: name 'word' is not defined

# %%
word='mango'

# %%
print(word<'guava')
# Out:
# False

# %%
print(word<'apple')
# Out:
# False

# %%
if (word<'banana'):
  print("Your word ,"+ word +'comes before banana')
elif word>'banana':
  print('your word ,'+ word+' come after banana')
else:
  print('got it,its banana')
# Out:
# your word ,mangocome after banana

# %%
dir(word)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
fruit='Hello  Joy'

# %%
fruit.find('na')
# Out:
# 2

# %%
fruit.find('an')
# Out:
# 1

# %%
fruit.replace('Joy','Amrit')
# Out:
# 'Hello  Amrit'

# %%
fruit
# Out:
# 'Hello  Joy'

# %%
#replace function gives the replaced function and not the output itself

# %%
#if the function returns then origi gives ori

# %%
fruit.replace('Raj','Amrit')
# Out:
# 'Hello  Joy'

# %%
fruit.search('Raj','Amrit')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-7d5fb7d6dfe9> in <module>
# ----> 1 fruit.search('Raj','Amrit')
#
# AttributeError: 'str' object has no attribute 'search'

# %%
great='     Hello Joy--------     '

# %%
great.lstrip()
# Out:
# 'Hello Joy--------'

# %%
great.rstrip()
# Out:
# 'kkkkkkkkkkkHello joy'

# %%
great='kkkkkkkkkkkHello joy'

# %%
great.lstrip('k')
# Out:
# 'NHello Joy'

# %%
great='kkkkkkkkkkkkkkNkkHello Joy'

# %%
great.lstrip('k')
# Out:
# 'NkkHello Joy'

# %%
#Quotes k baad aur letter k pehle ka poora kuch strip ho jaata h

# %%
print(id(str(50)))
# Out:
# 140693336858480

# %%
print(id('50'))
# Out:
# 140693336960944

# %%
e=12

# %%
~e
# Out:
# -13

# %%
e=15

# %%
~e
# Out:
# -16

# %%
g=10

# %%
~g
# Out:
# -11

# %%
x=13

# %%
~x
# Out:
# -14

# %%
#a negative number is stored as it's 2's complement in the system

# %%
a=10
b=False
c=20
a or b and c
# Out:
# 10

# %%
a=10
b=20
c=False
a or b and c
# Out:
# 10

# %%
a and c
# Out:
# False

# %%
a or b
# Out:
# 10

# %%
10 and False
# Out:
# False

# %%
10 and 20
# Out:
# 20

# %%
10 or 20
# Out:
# 10

# %%
pow(10,20)
# Out:
# 100000000000000000000

# %%
c=pow(10,20)

# %%
c
# Out:
# 100000000000000000000

# %%
def power(a,b):
    result=1
    for i in range(1,b+1):
      result*=a
      i+=1
    return result

# %%
pow(3,5)
# Out:
# 243

# %%
power(3,5)
# Out:
# 243

# %%
list=['0','1','3']

# %%
list1=list[0:1]

# %%
list1
# Out:
# ['0']

# %%
list1=list[0]

# %%
list1
# Out:
# '0'

# %%
#slicing gives you  list whereas indexing gives you element

# %%
l4.list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-916252b0ebc5> in <module>
# ----> 1 l4.list()
#
# NameError: name 'l4' is not defined

# %%
l4

# %%
#FUNCTION NOT RETURNING IT HAS MADE SOME CHANGES

# %%
L.list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1c680cc47ec2> in <module>
# ----> 1 L.list()
#
# NameError: name 'L' is not defined

# %%
l=list()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6612439dfe37> in <module>
# ----> 1 l=list()
#
# TypeError: 'list' object is not callable

# %%
L=list()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-75b1d6233be7> in <module>
# ----> 1 L=list()
#
# TypeError: 'list' object is not callable

# %%
l4='2'
