# %%
x=1

# %%
print(x)
# Out:
# 1

# %%
x=1+2**3//4*5

# %%
print(x)
# Out:
# 11

# %%
ddd=1+4

# %%
print(ddd)
# Out:
# 5

# %%
ddd='4'+'there'

# %%
ddd=ddd+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-807acbcd5415> in <module>()
# ----> 1 ddd=ddd+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
str<1>
# Out:
#   File "<ipython-input-19-295f1cced37c>", line 1
#     str<1>
#           ^
# SyntaxError: invalid syntax

# %%
sval='123'

# %%
ival=int(sval)

# %%
print(ival)
# Out:
# 123
